# %%
import pandas as pd
import numpy
import difflib
import seaborn as sns

# %%
df1 = pd.read_csv('10JS.csv')
df2 = pd.read_csv('10NoJS.csv')
df1['HTMLtext'] = df1['HTMLtext'].fillna('')

df1.head(0)
# Out:
# Empty DataFrame
# Columns: [HTML, HTMLtext, JavaScript, bodyContent, idTool, nameTool, urlTool]
# Index: []

# %%
for row in df1.itertuples():
# Out:
# 96238
# Yes
# 249
# Yes
# 8880
# Yes
# 9067
# Yes
# 121427
# Yes
# 17826
# Yes
# 10509
# Yes

# %%
df1
# Out:
#                                                 HTML HTMLtext JavaScript  \
# 0  <!DOCTYPE html><html lang="en"><head>\n    <me...                 Yes
# 1  {"error": 400, "type": "ScriptError", "descrip...                 Yes
# 2  <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...                 Yes
# 3  <!DOCTYPE html><!-- Built from commit cac18c87...                 Yes
# 4  <!DOCTYPE html><html lang="en"><head>\n    <me...                 Yes
# 5  <html xmlns="http://www.w3.org/1999/xhtml"><he...                 Yes
# 6  <html><head><title>(PS)2v2: Protein Structure ...                 Yes
#
#    bodyContent                                             idTool  \
# 0        96238    https://dev-openebench.bsc.es/monitor/tool/-cnn
# 1          249  https://dev-openebench.bsc.es/monitor/tool/100...
# 2         7872  https://dev-openebench.bsc.es/monitor/tool/100...
# 3         9067  https://dev-openebench.bsc.es/monitor/tool/net...
# ...

# %%
dataframe = pd.concat([df1, df2], ignore_index=True, sort=True)

# %%
dataframe.sort_values('idTool')

for row in itertuples()
    if row.
# Out:
#                                                  HTML HTMLtext JavaScript  \
# 0   <!DOCTYPE html><html lang="en"><head>\n    <me...                 Yes
# 9   \n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en">\...      NaN         No
# 4   <!DOCTYPE html><html lang="en"><head>\n    <me...                 Yes
# 12  <!DOCTYPE html>\n<html lang="en">\n  \n  \n  \...      NaN         No
# 2   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...                 Yes
# 8   <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.0 S...      NaN         No
# 1   {"error": 400, "type": "ScriptError", "descrip...                 Yes
# 7                                                 NaN      NaN         No
# 3   <!DOCTYPE html><!-- Built from commit cac18c87...                 Yes
# 13  <!DOCTYPE html>\r\n<!-- Built from commit cac1...      NaN         No
# 6   <html><head><title>(PS)2v2: Protein Structure ...                 Yes
# 11  \n<html><head><title>(PS)2v2: Protein Structur...      NaN         No
# ...
